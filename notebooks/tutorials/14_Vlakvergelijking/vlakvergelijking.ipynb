# %% [markdown]
# # Module vlakvergelijking

# %% [markdown]
# ## Initialize Sensor and Projector
# Do not change

# %%
#save the paths to the calibration files 
from sandbox import _calibration_dir
_calibprojector = _calibration_dir + "my_projector_calibration.json"
_calibsensor = _calibration_dir + "my_sensor_calibration.json"
_calibcolor = _calibration_dir + "my_color_calibration.json"

# %% [markdown]
# ## Choose the sensor
# for dummy sensor, use name="dummy"
# for kinectv2, use name="kinect_v2"

# %%
#Import Sensor
from sandbox.sensor import Sensor
sensor = Sensor(calibsensor=_calibsensor, calibcolor=_calibcolor, name="kinect_v2")
#sensor = Sensor(_calibsensor, name="dummy")
name="kinect_v2"

# Import projector
from sandbox.projector import Projector
projector = Projector(calibprojector=_calibprojector)
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='5f483153-f74b-4341-b9d3-cafc0b8da6b4'>
#   <div id="cdff488f-4a13-4e79-89da-e7d2fa92fe59" data-root-id="5f483153-f74b-4341-b9d3-cafc0b8da6b4" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"045091a4-c740-4ac4-bcfc-b250a3afc292":{"version":"3.1.1","title":"Bokeh Application","defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]}],"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"5f483153-f74b-4341-b9d3-cafc0b8da6b4"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"0a348760-aef5-409d-bad5-b7a03a88c3a4","attributes":{"plot_id":"5f483153-f74b-4341-b9d3-cafc0b8da6b4","comm_id":"f9ff1a6e147e4b6291a8c485d6b11337","client_comm_id":"88364805b469494ba1e558a9349b19e0"}}],"callbacks":{"type":"map"}}};
#   var render_items = [{"docid":"045091a4-c740-4ac4-bcfc-b250a3afc292","roots":{"5f483153-f74b-4341-b9d3-cafc0b8da6b4":"cdff488f-4a13-4e79-89da-e7d2fa92fe59"},"root_ids":["5f483153-f74b-4341-b9d3-cafc0b8da6b4"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   const is_dev = py_version.indexOf("+") !== -1 || py_version.indexOf("-") !== -1
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version && !is_dev) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# sandbox.sensor.sensor_api: INFO | JSON configuration loaded for sensor.
# sandbox.sensor.sensor_api: INFO | JSON configuration loaded for color sensor.
# sandbox.sensor.kinectV2: INFO | KinectV2 initialized.
# sandbox.projector.projector: INFO | JSON configuration loaded for projector
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# size 780 480
# Launching server at http://localhost:63948
# sandbox.projector.projector: INFO | Projector initialized and server started.
# Please position the browser window accordingly and enter fullscreen!

# %% [markdown]
# ## Load test data
# If we use the dummy sensor, we need to load test data.
# IF we use the kinect, we can run this code anyway.

# %%
import numpy as np
if name=="dummy":
    file = np.load("..\\06_LoadSaveTopoModule\saved_DEMs\DEM2.npz")
    frame = file['arr_0'] # + np.min(file['arr_0'])
    extent = np.asarray([0, frame.shape[1], 0, frame.shape[0], frame.min(), frame.max()])
    frame -= np.min(frame)

# %% [markdown]
# ## Initialize main thread for live update

# %%
from sandbox.main_thread import MainThread
main = MainThread(sensor=sensor, projector=projector, aruco=aruco if 'aruco' in globals() else None)
#main.load_frame(frame)
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='a5e18e63-97b5-428f-8dc8-67a9d9dad61a'>
#   <div id="bd6a61bc-a7c6-44a1-9821-fcbb9aa99d61" data-root-id="a5e18e63-97b5-428f-8dc8-67a9d9dad61a" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"995a1bd3-82c4-4a96-8aa4-0efa1f5df7cb":{"version":"3.1.1","title":"Bokeh Application","defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]}],"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"a5e18e63-97b5-428f-8dc8-67a9d9dad61a"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"16f3e582-a0f2-4bac-abd8-80715b955207","attributes":{"plot_id":"a5e18e63-97b5-428f-8dc8-67a9d9dad61a","comm_id":"58d6252195f04a2a8377a315daa887ca","client_comm_id":"7b0722305e33443c8367ca579f7c5020"}}],"callbacks":{"type":"map"}}};
#   var render_items = [{"docid":"995a1bd3-82c4-4a96-8aa4-0efa1f5df7cb","roots":{"a5e18e63-97b5-428f-8dc8-67a9d9dad61a":"bd6a61bc-a7c6-44a1-9821-fcbb9aa99d61"},"root_ids":["a5e18e63-97b5-428f-8dc8-67a9d9dad61a"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   const is_dev = py_version.indexOf("+") !== -1 || py_version.indexOf("-") !== -1
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version && !is_dev) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# sandbox.projector.contourlines: INFO | ContourLinesModule loaded successfully
# sandbox.projector.shading: INFO | LightSource set to address RWTH Aachen, Germany at datetime Wed Nov 20 11:52:26 2024
# sandbox.projector.cmap: INFO | CmapModule loaded successfully
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# sandbox.modules.widgets: INFO | widgets created

# %% [markdown]
# ## import modules and run the code
# Make sure the surface is flat before running this code

# %%
# Start the thread 
# Import the modules to use
from sandbox.modules import vlakvergelijking
from sandbox.modules import widgets
w = widgets()
Gradients = vlakvergelijking(extent=sensor.extent)
main.add_module(name='widgets', module=w)
main.add_module(name='vlakvergelijking', module=Gradients)
main.run()
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='1c6a895b-f10b-4581-96e5-fc2d64b8f29f'>
#   <div id="d232c997-4660-495c-a897-7ee01b240bab" data-root-id="1c6a895b-f10b-4581-96e5-fc2d64b8f29f" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"497e49bd-d1c9-4008-9248-66c7c821d861":{"version":"3.1.1","title":"Bokeh Application","defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]}],"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"1c6a895b-f10b-4581-96e5-fc2d64b8f29f"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"021a82d4-11c4-45dc-b616-ee9d61797ac6","attributes":{"plot_id":"1c6a895b-f10b-4581-96e5-fc2d64b8f29f","comm_id":"a2806e832de540698557c5f055aa26f6","client_comm_id":"106fcbce362a4b75836846b586da1a8b"}}],"callbacks":{"type":"map"}}};
#   var render_items = [{"docid":"497e49bd-d1c9-4008-9248-66c7c821d861","roots":{"1c6a895b-f10b-4581-96e5-fc2d64b8f29f":"d232c997-4660-495c-a897-7ee01b240bab"},"root_ids":["1c6a895b-f10b-4581-96e5-fc2d64b8f29f"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   const is_dev = py_version.indexOf("+") !== -1 || py_version.indexOf("-") !== -1
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version && !is_dev) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# sandbox.modules.widgets: INFO | widgets created
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# sandbox.modules.vlakvergelijking: INFO | VlakModules loaded successfully
# sandbox.main_thread: INFO | module widgets added to modules
# sandbox.main_thread: INFO | module vlakvergelijking added to modules
# sandbox.main_thread: INFO | Thread started or resumed...
# C:\Users\6802923\AppData\Local\anaconda3\envs\sandbox-env\lib\threading.py:870: RuntimeWarning: coroutine 'MainThread.thread_loop' was never awaited
#   self._target(*self._args, **self._kwargs)

# %% [markdown]
# # Tutorial
# Run the code below to do the tutorial.

# %%
main.stop()
main.run()
w.widgets_tutorial()
# Out:
# sandbox.main_thread: INFO | Thread stopped.
# sandbox.main_thread: INFO | Thread started or resumed...
# Column
#     [0] Markdown(str)
#     [1] Checkbox(name='Show exercise d..., value=True)

# %% [markdown]
# # Exercise 1

# %%
main.stop()
main.run()
w.widgets_exercise1()
# Out:
# sandbox.main_thread: INFO | Thread stopped.
# sandbox.main_thread: INFO | Thread started or resumed...
# Column
#     [0] Markdown(str)
#     [1] Checkbox(name='Show exercise d..., value=True)

# %% [markdown]
# # Exercise 2

# %%
main.stop()
main.run()
w.widgets_exercise2()
# Out:
# sandbox.main_thread: INFO | Thread stopped.
# sandbox.main_thread: INFO | Thread started or resumed...
# C:\Users\6802923\AppData\Local\anaconda3\envs\sandbox-env\lib\threading.py:870: RuntimeWarning: coroutine 'MainThread.thread_loop' was never awaited
#   self._target(*self._args, **self._kwargs)
# Column
#     [0] Markdown(str)
#     [1] Checkbox(name='Show exercise d..., value=True)

# %% [markdown]
# # Exercise 3

# %%
main.stop()
main.run()
w.widgets_exercise3()
# Out:
# sandbox.main_thread: INFO | Thread stopped.
# sandbox.main_thread: INFO | Thread started or resumed...
# C:\Users\6802923\AppData\Local\anaconda3\envs\sandbox-env\lib\threading.py:870: RuntimeWarning: coroutine 'MainThread.thread_loop' was never awaited
#   self._target(*self._args, **self._kwargs)
# Column
#     [0] Markdown(str)
#     [1] Checkbox(name='Show exercise d..., value=True)

# %% [markdown]
# # Exercise 4

# %%
main.stop()
main.run()
w.widgets_exercise4()
# Out:
# sandbox.main_thread: INFO | Thread stopped.
# sandbox.main_thread: INFO | Thread started or resumed...
# C:\Users\6802923\AppData\Local\anaconda3\envs\sandbox-env\lib\threading.py:870: RuntimeWarning: coroutine 'MainThread.thread_loop' was never awaited
#   self._target(*self._args, **self._kwargs)
# Column
#     [0] Markdown(str)
#     [1] Checkbox(name='Show exercise d..., value=True)
#     [2] Button(button_type='primary', name='Show a vector')
#     [3] Checkbox(name='Find vector equation')

# %% [markdown]
# # Exercise 5

# %%
main.stop()
main.run()
w.widgets_exercise5()
# Out:
# sandbox.main_thread: INFO | Thread stopped.
# sandbox.main_thread: INFO | Thread started or resumed...
# C:\Users\6802923\AppData\Local\anaconda3\envs\sandbox-env\lib\threading.py:870: RuntimeWarning: coroutine 'MainThread.thread_loop' was never awaited
#   self._target(*self._args, **self._kwargs)
# Column
#     [0] Markdown(str)
#     [1] Checkbox(name='Show exercise d..., value=True)

# %% [markdown]
# # Exercise 6

# %%
main.stop()
main.run()
w.widgets_exercise6()
# Out:
# sandbox.main_thread: INFO | Thread stopped.
# sandbox.main_thread: INFO | Thread started or resumed...
# C:\Users\6802923\AppData\Local\anaconda3\envs\sandbox-env\lib\threading.py:870: RuntimeWarning: coroutine 'MainThread.thread_loop' was never awaited
#   self._target(*self._args, **self._kwargs)
# Column
#     [0] Markdown(str)
#     [1] Checkbox(name='Show exercise d...)
# did not find enough or too many points 4
# did not find enough or too many points 2
# did not find enough or too many points 2
# did not find enough or too many points 2
# did not find enough or too many points 2
# did not find enough or too many points 2
# did not find enough or too many points 2
# did not find enough or too many points 2
# did not find enough or too many points 2

# %% [markdown]
# # Exercise 7

# %%
main.stop()
main.run()
w.widgets_exercise7()

# %% [markdown]
# # Exercise 8

# %%
main.stop()
main.run()
w.widgets_exercise8()

# %% [markdown]
# # Exercise 9

# %%
main.stop()
main.run()
w.widgets_exercise9()

# %%
main.stop()
# Out:
# sandbox.main_thread: INFO | Thread stopped.

# %% [markdown]
# # Test

# %%
main.stop()
main.run()
w.widgets_test()
# Out:
# sandbox.main_thread: INFO | Thread stopped.
# sandbox.main_thread: INFO | Thread started or resumed...
# C:\Users\6802923\AppData\Local\anaconda3\envs\sandbox-env\lib\threading.py:870: RuntimeWarning: coroutine 'MainThread.thread_loop' was never awaited
#   self._target(*self._args, **self._kwargs)
# Column
#     [0] Markdown(str)
#     [1] IntSlider(bar_color='#0000ff', end=400, name='x', start=1, value=100)
#     [2] IntSlider(bar_color='#0000ff', end=400, name='y', start=1, value=100)
# color shape (177, 312, 3)
# color shape (177, 312, 3)
# 311 149
# color shape (177, 312, 3)
# 311 147
# color shape (177, 312, 3)
# 311 148
# color shape (177, 312, 3)
# 311 148
# color shape (177, 312, 3)
# 311 150
# color shape (177, 312, 3)
# 311 149
# color shape (177, 312, 3)
# 311 149
# color shape (177, 312, 3)
# 311 149
# color shape (177, 312, 3)
# 311 149
# color shape (177, 312, 3)
# 311 149
# color shape (177, 312, 3)
# 311 149
# color shape (177, 312, 3)
# 310 149
# color shape (177, 312, 3)
# 311 149
# color shape (177, 312, 3)
# 310 149
# color shape (177, 312, 3)
# color shape (177, 312, 3)
# color shape (177, 312, 3)
# color shape (177, 312, 3)
# 311 174
# color shape (177, 312, 3)
# color shape (177, 312, 3)
# color shape (177, 312, 3)
# color shape (177, 312, 3)
# color shape (177, 312, 3)
# color shape (177, 312, 3)
# color shape (177, 312, 3)
# color shape (177, 312, 3)
# color shape (177, 312, 3)
# 311 170
# color shape (177, 312, 3)
# 311 171
# color shape (177, 312, 3)
# 311 171
# color shape (177, 312, 3)
# color shape (177, 312, 3)
# color shape (177, 312, 3)
# 310 3
# color shape (177, 312, 3)
# 311 4
# color shape (177, 312, 3)
# color shape (177, 312, 3)
# color shape (177, 312, 3)
# color shape (177, 312, 3)
# color shape (177, 312, 3)
# color shape (177, 312, 3)
# color shape (177, 312, 3)
# color shape (177, 312, 3)
# 97 101
# color shape (177, 312, 3)
# 95 105
# color shape (177, 312, 3)
# 96 105
# color shape (177, 312, 3)
# 96 105
# color shape (177, 312, 3)
# 96 105
# color shape (177, 312, 3)
# color shape (177, 312, 3)
# 52 69
# color shape (177, 312, 3)
# 52 69
# color shape (177, 312, 3)
# 52 69
# color shape (177, 312, 3)
# 52 69
# color shape (177, 312, 3)
# 52 69
# color shape (177, 312, 3)
# 51 69
# color shape (177, 312, 3)
# color shape (177, 312, 3)
# 29 66
# color shape (177, 312, 3)
# 27 67
# color shape (177, 312, 3)
# 27 67
# color shape (177, 312, 3)
# color shape (177, 312, 3)
# color shape (177, 312, 3)
# 18 66
# color shape (177, 312, 3)
# 18 66
# color shape (177, 312, 3)
# 17 66
# color shape (177, 312, 3)
# 18 67
# color shape (177, 312, 3)
# 18 67

# %%
main.stop()
# Out:
# sandbox.main_thread: INFO | Thread stopped.
