# %% [markdown]
# # Module vlakvergelijking

# %% [markdown]
# ## Initialize Sensor and Projector
# Do not change

# %%
#save the paths to the calibration files 
from sandbox import _calibration_dir
_calibprojector = _calibration_dir + "my_projector_calibration.json"
_calibsensor = _calibration_dir + "my_sensor_calibration.json"
_calibcolor = _calibration_dir + "my_color_calibration.json"

# %% [markdown]
# ## Choose the sensor
# for dummy sensor, use name="dummy"
# for kinectv2, use name="kinect_v2"

# %%
#Import Sensor
from sandbox.sensor import Sensor
sensor = Sensor(calibsensor=_calibsensor, calibcolor=_calibcolor, name="kinect_v2")
#sensor = Sensor(_calibsensor, name="dummy")
name="kinect_v2"

# Import projector
from sandbox.projector import Projector
projector = Projector(calibprojector=_calibprojector)
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='d374323a-85d1-4289-a0bb-e70183048931'>
#   <div id="c47b7ad4-0f21-48dc-9705-6b947a32cc1d" data-root-id="d374323a-85d1-4289-a0bb-e70183048931" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"537117d4-12eb-412d-827e-3a2ef89f7ac3":{"version":"3.1.1","title":"Bokeh Application","defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]}],"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"d374323a-85d1-4289-a0bb-e70183048931"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"ed7eac19-5f55-46f1-8aec-8b9f6c33c320","attributes":{"plot_id":"d374323a-85d1-4289-a0bb-e70183048931","comm_id":"2ef6519e8a554eccbeffa49bf128f8aa","client_comm_id":"865717500c4c4a6099fdb46ee9ffa18b"}}],"callbacks":{"type":"map"}}};
#   var render_items = [{"docid":"537117d4-12eb-412d-827e-3a2ef89f7ac3","roots":{"d374323a-85d1-4289-a0bb-e70183048931":"c47b7ad4-0f21-48dc-9705-6b947a32cc1d"},"root_ids":["d374323a-85d1-4289-a0bb-e70183048931"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   const is_dev = py_version.indexOf("+") !== -1 || py_version.indexOf("-") !== -1
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version && !is_dev) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# sandbox.sensor.sensor_api: INFO | JSON configuration loaded for sensor.
# sandbox.sensor.sensor_api: INFO | JSON configuration loaded for color sensor.
# sandbox.sensor.kinectV2: INFO | KinectV2 initialized.
# sandbox.projector.projector: INFO | JSON configuration loaded for projector
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# size 780 480
# Launching server at http://localhost:59596
# sandbox.projector.projector: INFO | Projector initialized and server started.
# Please position the browser window accordingly and enter fullscreen!

# %% [markdown]
# ## Load test data
# If we use the dummy sensor, we need to load test data.
# IF we use the kinect, we can run this code anyway.

# %%
import numpy as np
if name=="dummy":
    file = np.load("..\\06_LoadSaveTopoModule\saved_DEMs\DEM2.npz")
    frame = file['arr_0'] # + np.min(file['arr_0'])
    extent = np.asarray([0, frame.shape[1], 0, frame.shape[0], frame.min(), frame.max()])
    frame -= np.min(frame)

# %% [markdown]
# ## Initialize main thread for live update

# %%
from sandbox.main_thread import MainThread
main = MainThread(sensor=sensor, projector=projector, aruco=aruco if 'aruco' in globals() else None)
#main.load_frame(frame)
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='547c1ca9-8df0-423d-9907-40845cda48ce'>
#   <div id="d2e89843-cf3e-4751-83c5-80f5ec6a832e" data-root-id="547c1ca9-8df0-423d-9907-40845cda48ce" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"6978c4a0-4585-4106-8d66-6382fadf4317":{"version":"3.1.1","title":"Bokeh Application","defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]}],"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"547c1ca9-8df0-423d-9907-40845cda48ce"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"f32b0aa3-a5d3-453a-a1c3-6aaaed34a219","attributes":{"plot_id":"547c1ca9-8df0-423d-9907-40845cda48ce","comm_id":"943674e57abb4745a60506a1e03a1108","client_comm_id":"e4688ee81eae4be4a702b2d9e49d0e5c"}}],"callbacks":{"type":"map"}}};
#   var render_items = [{"docid":"6978c4a0-4585-4106-8d66-6382fadf4317","roots":{"547c1ca9-8df0-423d-9907-40845cda48ce":"d2e89843-cf3e-4751-83c5-80f5ec6a832e"},"root_ids":["547c1ca9-8df0-423d-9907-40845cda48ce"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   const is_dev = py_version.indexOf("+") !== -1 || py_version.indexOf("-") !== -1
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version && !is_dev) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# sandbox.projector.contourlines: INFO | ContourLinesModule loaded successfully
# sandbox.projector.shading: INFO | LightSource set to address RWTH Aachen, Germany at datetime Tue Nov 26 15:14:01 2024
# sandbox.projector.cmap: INFO | CmapModule loaded successfully
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# sandbox.modules.widgets: INFO | widgets created

# %% [markdown]
# ## import modules and run the code
# Make sure the surface is flat before running this code

# %%
# Start the thread 
# Import the modules to use
from sandbox.modules import vlakvergelijking
from sandbox.modules import widgets
w = widgets()
Gradients = vlakvergelijking(extent=sensor.extent)
main.add_module(name='widgets', module=w)
main.add_module(name='vlakvergelijking', module=Gradients)
main.run()
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='afb3306b-f896-4007-a375-e0f76dda180e'>
#   <div id="a1a811c8-ab24-430c-8eb9-450845419481" data-root-id="afb3306b-f896-4007-a375-e0f76dda180e" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"122c553a-0b07-44b5-ab4a-a32d153595c3":{"version":"3.1.1","title":"Bokeh Application","defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]}],"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"afb3306b-f896-4007-a375-e0f76dda180e"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"8c68dd10-37f8-458f-8538-137c5fb9f84f","attributes":{"plot_id":"afb3306b-f896-4007-a375-e0f76dda180e","comm_id":"124a0b1b410347feb9f82e8e68a79a05","client_comm_id":"510343b6434149b5839650aa73b80ccb"}}],"callbacks":{"type":"map"}}};
#   var render_items = [{"docid":"122c553a-0b07-44b5-ab4a-a32d153595c3","roots":{"afb3306b-f896-4007-a375-e0f76dda180e":"a1a811c8-ab24-430c-8eb9-450845419481"},"root_ids":["afb3306b-f896-4007-a375-e0f76dda180e"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   const is_dev = py_version.indexOf("+") !== -1 || py_version.indexOf("-") !== -1
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version && !is_dev) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# sandbox.modules.widgets: INFO | widgets created
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# sandbox.modules.vlakvergelijking: INFO | VlakModules loaded successfully
# sandbox.main_thread: INFO | module widgets added to modules
# sandbox.main_thread: INFO | module vlakvergelijking added to modules
# sandbox.main_thread: INFO | Thread started or resumed...
# shape hex 149
# C:\Users\6802923\AppData\Local\anaconda3\envs\sandbox-env\lib\threading.py:870: RuntimeWarning: coroutine 'MainThread.thread_loop' was never awaited
#   self._target(*self._args, **self._kwargs)
# red [[92, 239]]
# blue [[68, 252]]
# green []
# dark green []
# shape hex 149
# red [[91, 240]]
# blue [[68, 252]]
# green []
# dark green []

# %% [markdown]
# # Tutorial
# Run the code below to do the tutorial.

# %%
main.stop()
main.run()
w.widgets_tutorial()
# Out:
# sandbox.main_thread: INFO | Thread stopped.
# sandbox.main_thread: INFO | Thread started or resumed...
# C:\Users\6802923\AppData\Local\anaconda3\envs\sandbox-env\lib\threading.py:870: RuntimeWarning: coroutine 'MainThread.thread_loop' was never awaited
#   self._target(*self._args, **self._kwargs)
# Column
#     [0] Markdown(str)
#     [1] Checkbox(name='Show exercise d..., value=True)

# %% [markdown]
# # Exercise 1

# %%
main.stop()
main.run()
w.widgets_exercise1()
# Out:
# sandbox.main_thread: INFO | Thread stopped.
# sandbox.main_thread: INFO | Thread started or resumed...
# C:\Users\6802923\AppData\Local\anaconda3\envs\sandbox-env\lib\threading.py:870: RuntimeWarning: coroutine 'MainThread.thread_loop' was never awaited
#   self._target(*self._args, **self._kwargs)
# Column
#     [0] Markdown(str)
#     [1] Checkbox(name='Show exercise d..., value=True)

# %% [markdown]
# # Exercise 2

# %%
main.stop()
main.run()
w.widgets_exercise2()
# Out:
# sandbox.main_thread: INFO | Thread stopped.
# sandbox.main_thread: INFO | Thread started or resumed...
# C:\Users\6802923\AppData\Local\anaconda3\envs\sandbox-env\lib\threading.py:870: RuntimeWarning: coroutine 'MainThread.thread_loop' was never awaited
#   self._target(*self._args, **self._kwargs)
# Column
#     [0] Markdown(str)
#     [1] Checkbox(name='Show exercise d..., value=True)

# %% [markdown]
# # Exercise 3

# %%
main.stop()
main.run()
w.widgets_exercise3()
# Out:
# sandbox.main_thread: INFO | Thread stopped.
# sandbox.main_thread: INFO | Thread started or resumed...
# C:\Users\6802923\AppData\Local\anaconda3\envs\sandbox-env\lib\threading.py:870: RuntimeWarning: coroutine 'MainThread.thread_loop' was never awaited
#   self._target(*self._args, **self._kwargs)
# Column
#     [0] Markdown(str)
#     [1] Checkbox(name='Show exercise d..., value=True)

# %% [markdown]
# # Exercise 4

# %%
main.stop()
main.run()
w.widgets_exercise4()
# Out:
# sandbox.main_thread: INFO | Thread stopped.
# sandbox.main_thread: INFO | Thread started or resumed...
# C:\Users\6802923\AppData\Local\anaconda3\envs\sandbox-env\lib\threading.py:870: RuntimeWarning: coroutine 'MainThread.thread_loop' was never awaited
#   self._target(*self._args, **self._kwargs)
# Column
#     [0] Markdown(str)
#     [1] Checkbox(name='Show exercise d..., value=True)
#     [2] Button(button_type='primary', name='Show a vector')
# [[91, 239, 0], [68, 252, 1]]
# [[91, 240, 0], [68, 252, 3]]
# [[91, 240, 0], [68, 252, 4]]
# [[91, 240, 0], [68, 252, 17]]
# [[38, 211, 0], [59, 182, 7]]
# [[49, 198, 0], [67, 173, 2]]
# [[48, 200, 0], [67, 173, 3]]
# [[50, 199, 0], [67, 174, 3]]
# [[50, 194, 0], [68, 172, 2]]
# [[38, 179, 0], [63, 164, 3]]
# [[34, 168, 0], [63, 159, 3]]
# [[35, 167, 0], [63, 159, 3]]
# [[34, 169, 0], [63, 159, 2]]
# [[25, 175, 0], [54, 163, 3]]
# [[73, 162, 0], [52, 174, 6]]
# [[73, 167, 0], [54, 189, 2]]
# [[73, 167, 0], [54, 189, 2]]
# [[73, 167, 0], [54, 189, 2]]
# [[73, 167, 0], [54, 189, 2]]
# [[73, 167, 0], [54, 189, 2]]
# [[73, 167, 0], [54, 189, 2]]
# [[73, 167, 0], [55, 186, 8]]
# [[73, 167, 0], [54, 189, 5]]
# [[75, 167, 0], [53, 188, 14]]
# [[72, 168, 0], [53, 188, 2]]
# [[72, 168, 0], [53, 189, 4]]
# [[72, 168, 0], [53, 189, 2]]
# [[72, 168, 0], [53, 189, 2]]
# [[72, 167, 0], [53, 188, 2]]
# [[72, 168, 0], [53, 189, 2]]
# [[72, 168, 0], [53, 189, 1]]
# [[72, 168, 0], [53, 188, 2]]
# [[72, 168, 0], [53, 188, 2]]
# [[72, 167, 0], [53, 189, 2]]
# [[72, 168, 0], [53, 188, 2]]
# [[72, 168, 0], [53, 189, 2]]
# [[72, 168, 0], [53, 189, 3]]
# [[71, 169, 0], [53, 188, 4]]
# [[74, 166, 0], [55, 189, 6]]
# [[68, 173, 0], [50, 193, 2]]
# [[82, 157, 0], [98, 144, 1]]
# [[82, 157, 0], [98, 144, 1]]
# [[81, 157, 0], [112, 129, 2]]
# [[81, 157, 0], [112, 130, 2]]
# [[81, 157, 0], [112, 130, 2]]
# [[81, 157, 0], [112, 130, 2]]
# [[81, 157, 0], [112, 130, 2]]
# [[81, 157, 0], [112, 130, 2]]
# [[81, 157, 0], [112, 130, 2]]
# [[81, 157, 0], [112, 130, 2]]
# [[81, 157, 0], [112, 130, 2]]
# [[81, 157, 0], [112, 130, 2]]
# [[81, 157, 0], [112, 130, 2]]
# [[81, 157, 0], [112, 129, 6]]
# [[82, 154, 0], [112, 129, 2]]
# [[81, 157, 0], [112, 129, 2]]
# [[81, 157, 0], [112, 129, 2]]
# [[81, 159, 0], [112, 125, 2]]
# [[81, 159, 0], [112, 125, 2]]
# [[81, 159, 0], [112, 125, 2]]
# [[81, 159, 0], [112, 125, 2]]
# [[81, 159, 0], [112, 125, 2]]
# [[82, 157, 0], [108, 115, 6]]
# [[80, 155, 0], [112, 115, 1]]
# [[80, 155, 0], [113, 112, 2]]
# [[80, 155, 0], [113, 112, 1]]
# [[80, 155, 0], [112, 115, 1]]
# [[80, 155, 0], [112, 115, 1]]
# [[80, 157, 0], [113, 112, 1]]
# [[80, 156, 0], [112, 115, 2]]
# [[80, 156, 0], [113, 112, 2]]
# [[80, 155, 0], [113, 112, 2]]
# [[80, 155, 0], [112, 115, 2]]
# [[80, 155, 0], [114, 112, 2]]
# [[80, 156, 0], [112, 115, 1]]
# [[80, 155, 0], [112, 115, 1]]
# [[80, 155, 0], [113, 112, 2]]
# [[80, 155, 0], [112, 115, 2]]
# [[80, 155, 0], [115, 117, 2]]
# [[80, 155, 0], [113, 112, 1]]
# [[80, 156, 0], [113, 112, 2]]
# [[80, 155, 0], [112, 115, 2]]
# [[80, 155, 0], [112, 115, 2]]
# [[80, 155, 0], [112, 115, 2]]
# [[80, 155, 0], [112, 115, 2]]
# [[80, 158, 0], [112, 115, 3]]
# [[79, 161, 0], [112, 112, 1]]
# [[79, 161, 0], [112, 111, 1]]
# [[80, 155, 0], [112, 114, 1]]
# [[80, 155, 0], [115, 116, 1]]
# [[80, 155, 0], [115, 116, 1]]
# [[79, 161, 0], [115, 116, 1]]
# [[79, 161, 0], [115, 117, 1]]
# [[79, 161, 0], [115, 116, 1]]
# [[80, 155, 0], [115, 116, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[79, 161, 0], [115, 116, 1]]
# [[80, 155, 0], [115, 116, 1]]
# [[80, 155, 0], [115, 116, 1]]
# [[79, 160, 0], [115, 116, 1]]
# [[79, 161, 0], [115, 116, 1]]
# [[79, 161, 0], [115, 116, 1]]
# [[80, 155, 0], [115, 116, 1]]
# [[79, 161, 0], [115, 116, 1]]
# [[79, 161, 0], [115, 117, 1]]
# [[79, 161, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[79, 161, 0], [115, 117, 1]]
# [[79, 161, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 116, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[79, 161, 0], [115, 117, 1]]
# [[80, 155, 0], [116, 116, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[79, 161, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[79, 161, 0], [115, 117, 1]]
# [[79, 161, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 116, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[79, 161, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[80, 155, 0], [114, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[80, 155, 0], [112, 111, 1]]
# [[80, 155, 0], [115, 116, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[79, 161, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[79, 161, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[79, 161, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[79, 161, 0], [115, 117, 1]]
# [[79, 161, 0], [115, 117, 1]]
# [[79, 161, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[79, 161, 0], [115, 117, 1]]
# [[79, 161, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[79, 161, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[79, 160, 0], [115, 117, 1]]
# [[79, 161, 0], [115, 116, 1]]
# [[79, 161, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[79, 161, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 116, 1]]
# [[80, 155, 0], [115, 116, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[79, 161, 0], [115, 116, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[79, 161, 0], [115, 117, 1]]
# [[79, 161, 0], [112, 111, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[79, 161, 0], [115, 117, 1]]
# [[79, 161, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[80, 155, 0], [112, 111, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[79, 161, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[79, 161, 0], [115, 117, 1]]
# [[79, 161, 0], [112, 111, 1]]
# [[80, 155, 0], [115, 116, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[79, 161, 0], [115, 116, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 116, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[79, 161, 0], [115, 116, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[79, 161, 0], [112, 111, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 116, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[79, 161, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 116, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[79, 161, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 116, 1]]
# [[79, 161, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[79, 160, 0], [112, 111, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 116, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[79, 161, 0], [115, 116, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[79, 161, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 116, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[79, 161, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 116, 1]]
# [[80, 155, 0], [115, 116, 1]]
# [[79, 161, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 116, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[79, 161, 0], [115, 116, 1]]
# [[79, 161, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[79, 161, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 116, 1]]
# [[80, 155, 0], [115, 116, 1]]
# [[79, 161, 0], [115, 117, 1]]
# [[79, 161, 0], [115, 117, 1]]
# [[79, 161, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[79, 161, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[79, 161, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[79, 161, 0], [115, 116, 1]]
# [[79, 161, 0], [115, 117, 1]]
# [[79, 161, 0], [115, 116, 1]]
# [[80, 155, 0], [115, 116, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[80, 155, 0], [115, 116, 1]]
# [[80, 155, 0], [115, 117, 1]]
# [[79, 161, 0], [115, 117, 1]]
# [[79, 161, 0], [115, 117, 1]]
# [[79, 161, 0], [113, 111, 1]]
# [[81, 158, 0], [110, 144, 1]]
# [[81, 158, 0], [109, 143, 1]]
# [[81, 158, 0], [110, 144, 1]]
# [[81, 157, 0], [111, 142, 1]]
# [[81, 157, 0], [110, 144, 1]]
# [[81, 157, 0], [110, 144, 1]]
# [[81, 158, 0], [46, 249, 18]]
# [[81, 158, 0], [110, 144, 1]]
# [[81, 157, 0], [110, 144, 1]]
# [[81, 157, 0], [110, 144, 1]]
# [[81, 157, 0], [110, 144, 1]]
# [[81, 157, 0], [110, 144, 1]]
# [[81, 158, 0], [110, 144, 1]]
# [[81, 158, 0], [110, 144, 2]]
# [[81, 158, 0], [110, 144, 1]]
# [[81, 157, 0], [110, 144, 1]]
# [[81, 157, 0], [110, 144, 1]]
# [[81, 158, 0], [110, 144, 1]]
# [[79, 238, 0], [107, 233, 17]]
# [[80, 237, 0], [107, 233, 18]]
# [[79, 238, 0], [107, 234, 18]]
# [[79, 238, 0], [110, 234, 18]]
# [[79, 238, 0], [108, 240, 18]]
# [[79, 238, 0], [107, 233, 18]]
# [[79, 238, 0], [107, 233, 18]]
# [[79, 238, 0], [112, 237, 18]]
# [[79, 238, 0], [107, 233, 18]]
# [[97, 88, 0], [128, 97, 3]]
# [[84, 83, 0], [112, 85, 1]]
# [[84, 83, 0], [112, 90, 1]]
# [[83, 85, 0], [110, 87, 2]]
# [[81, 85, 0], [113, 87, 1]]
# [[82, 84, 0], [113, 87, 1]]
# [[82, 84, 0], [113, 87, 1]]
# [[82, 84, 0], [113, 87, 1]]
# [[109, 297, 0], [133, 270, 20]]
# [[111, 295, 0], [137, 269, 20]]
# [[67, 82, 0], [34, 79, 6]]
# [[76, 83, 0], [43, 76, 2]]
# [[76, 82, 0], [43, 77, 2]]
# [[76, 82, 0], [43, 77, 2]]
# [[76, 109, 0], [44, 104, 2]]
# [[76, 109, 0], [44, 104, 2]]
# [[73, 106, 0], [43, 99, 6]]
# [[76, 134, 0], [44, 134, 2]]
# [[76, 134, 0], [43, 134, 2]]
# [[76, 134, 0], [44, 134, 5]]
# [[67, 161, 0], [37, 167, 7]]
# [[103, 278, 0], [52, 269, 19]]
# [[121, 284, 0], [126, 229, 18]]
# [[124, 282, 0], [128, 232, 18]]
# [[75, 168, 0], [80, 107, 0]]
# [[75, 168, 0], [80, 107, 0]]
# [[75, 168, 0], [80, 107, 0]]
# [[75, 168, 0], [83, 111, 0]]
# [[40, 142, 0], [40, 84, 0]]
# [[40, 142, 0], [40, 84, 0]]
# [[40, 142, 0], [40, 84, 0]]
# [[74, 160, 0], [53, 119, 9]]
# [[120, 206, 0], [111, 153, 3]]
# [[72, 180, 0], [58, 235, 18]]
# [[77, 150, 0], [63, 106, 6]]
# [[73, 161, 0], [46, 122, 3]]
# [[73, 161, 0], [43, 115, 3]]
# [[73, 160, 0], [43, 111, 2]]
# [[73, 160, 0], [44, 111, 3]]
# [[74, 160, 0], [43, 110, 3]]
# [[73, 160, 0], [44, 111, 3]]
# [[73, 160, 0], [43, 110, 3]]
# [[73, 160, 0], [43, 110, 3]]
# [[73, 160, 0], [42, 110, 3]]
# [[74, 160, 0], [44, 111, 3]]
# [[73, 160, 0], [42, 110, 3]]
# [[74, 160, 0], [42, 110, 3]]
# [[73, 160, 0], [42, 110, 3]]
# [[73, 160, 0], [42, 110, 3]]
# [[73, 160, 0], [42, 110, 3]]
# [[74, 160, 0], [42, 110, 3]]
# [[73, 160, 0], [42, 110, 3]]
# [[73, 162, 0], [44, 127, 8]]
# [[73, 162, 0], [43, 129, 6]]
# [[73, 161, 0], [40, 124, 5]]
# [[73, 161, 0], [40, 122, 5]]
# [[73, 161, 0], [40, 123, 5]]
# [[72, 161, 0], [36, 118, 4]]
# [[72, 160, 0], [36, 118, 3]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 106, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 106, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [44, 106, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [44, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [44, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [44, 106, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [44, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [44, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [44, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [44, 107, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [44, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [44, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [44, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [44, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [44, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [44, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [44, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [44, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 104, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [44, 106, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [44, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [44, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# ...
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [44, 106, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 106, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]
# [[73, 157, 0], [45, 105, 2]]

# %% [markdown]
# # Exercise 5

# %%
main.stop()
main.run()
w.widgets_exercise5()
# Out:
# sandbox.main_thread: INFO | Thread stopped.
# sandbox.main_thread: INFO | Thread started or resumed...
# C:\Users\6802923\AppData\Local\anaconda3\envs\sandbox-env\lib\threading.py:870: RuntimeWarning: coroutine 'MainThread.thread_loop' was never awaited
#   self._target(*self._args, **self._kwargs)
# Column
#     [0] Markdown(str)
#     [1] Checkbox(name='Show exercise d..., value=True)
#     [2] Button(button_type='primary', name='Show a vector')

# %% [markdown]
# # Exercise 6

# %%
main.stop()
main.run()
w.widgets_exercise6()
# Out:
# sandbox.main_thread: INFO | Thread stopped.
# sandbox.main_thread: INFO | Thread started or resumed...
# C:\Users\6802923\AppData\Local\anaconda3\envs\sandbox-env\lib\threading.py:870: RuntimeWarning: coroutine 'MainThread.thread_loop' was never awaited
#   self._target(*self._args, **self._kwargs)
# Column
#     [0] Markdown(str)
#     [1] Checkbox(name='Show exercise d..., value=True)
#     [2] Button(button_type='primary', name='Show a vector')

# %% [markdown]
# # Exercise 7

# %%
main.stop()
main.run()
w.widgets_exercise7()
# Out:
# sandbox.main_thread: INFO | Thread stopped.
# sandbox.main_thread: INFO | Thread started or resumed...
# C:\Users\6802923\AppData\Local\anaconda3\envs\sandbox-env\lib\threading.py:870: RuntimeWarning: coroutine 'MainThread.thread_loop' was never awaited
#   self._target(*self._args, **self._kwargs)
# Column
#     [0] Markdown(str)
#     [1] Checkbox(name='Show exercise d..., value=True)
#     [2] Button(button_type='primary', name='Show a vector')

# %% [markdown]
# # Exercise 8

# %%
main.stop()
main.run()
w.widgets_exercise8()
# Out:
# sandbox.main_thread: INFO | Thread stopped.
# sandbox.main_thread: INFO | Thread started or resumed...
# C:\Users\6802923\AppData\Local\anaconda3\envs\sandbox-env\lib\threading.py:870: RuntimeWarning: coroutine 'MainThread.thread_loop' was never awaited
#   self._target(*self._args, **self._kwargs)
# Column
#     [0] Markdown(str)
#     [1] Checkbox(name='Show exercise d..., value=True)
#     [2] Button(button_type='primary', name='Show a vector')

# %% [markdown]
# # Exercise 9

# %%
main.stop()
main.run()
w.widgets_exercise9()
# Out:
# sandbox.main_thread: INFO | Thread stopped.
# sandbox.main_thread: INFO | Thread started or resumed...
# C:\Users\6802923\AppData\Local\anaconda3\envs\sandbox-env\lib\threading.py:870: RuntimeWarning: coroutine 'MainThread.thread_loop' was never awaited
#   self._target(*self._args, **self._kwargs)
# Column
#     [0] Markdown(str)
#     [1] Checkbox(name='Show exercise d..., value=True)
#     [2] Button(button_type='primary', name='Show a vector')

# %%
main.stop()
# Out:
# sandbox.main_thread: INFO | Thread stopped.

# %% [markdown]
# # Exercise 10

# %%
main.stop()
main.run()
w.widgets_exercise10()
# Out:
# sandbox.main_thread: INFO | Thread stopped.
# sandbox.main_thread: INFO | Thread started or resumed...
# C:\Users\6802923\AppData\Local\anaconda3\envs\sandbox-env\lib\threading.py:870: RuntimeWarning: coroutine 'MainThread.thread_loop' was never awaited
#   self._target(*self._args, **self._kwargs)
# Column
#     [0] Markdown(str)
#     [1] Checkbox(name='Show exercise d..., value=True)
# sandbox.main_thread: CRITICAL | division by zero
# Traceback (most recent call last):
#   File "c:\users\6802923\documents\github\open_ar_sandbox\sandbox\main_thread.py", line 181, in update
#     [a,b] = self.modules[key].update(self.sb_params, self.w_params)
#   File "c:\users\6802923\documents\github\open_ar_sandbox\sandbox\modules\vlakvergelijking.py", line 88, in update
#     frame, ax, cmap, extent = self.plot(frame, ax, colors, cmap, extent)
#   File "c:\users\6802923\documents\github\open_ar_sandbox\sandbox\modules\vlakvergelijking.py", line 126, in plot
#     self.plot_exercise_10(ax, colors, frame, self.exercises.exercise_10())
#   File "c:\users\6802923\documents\github\open_ar_sandbox\sandbox\modules\vlakvergelijking.py", line 441, in plot_exercise_10
#     self.plane_format_z(ax, eq, 1)
#   File "c:\users\6802923\documents\github\open_ar_sandbox\sandbox\modules\vlakvergelijking.py", line 651, in plane_format_z
#     z_1_equation = [round(round(equation[0]*10)/round(equation[2]*10)), round(round(equation[1]*10)/round(equation[2]*10)), 1, round(round(equation[3]*10)/round(equation[2]*10))]
# ZeroDivisionError: division by zero
# Traceback (most recent call last):
#   File "c:\users\6802923\documents\github\open_ar_sandbox\sandbox\main_thread.py", line 181, in update
#     [a,b] = self.modules[key].update(self.sb_params, self.w_params)
#   File "c:\users\6802923\documents\github\open_ar_sandbox\sandbox\modules\vlakvergelijking.py", line 88, in update
#     frame, ax, cmap, extent = self.plot(frame, ax, colors, cmap, extent)
#   File "c:\users\6802923\documents\github\open_ar_sandbox\sandbox\modules\vlakvergelijking.py", line 126, in plot
#     self.plot_exercise_10(ax, colors, frame, self.exercises.exercise_10())
#   File "c:\users\6802923\documents\github\open_ar_sandbox\sandbox\modules\vlakvergelijking.py", line 441, in plot_exercise_10
#     self.plane_format_z(ax, eq, 1)
#   File "c:\users\6802923\documents\github\open_ar_sandbox\sandbox\modules\vlakvergelijking.py", line 651, in plane_format_z
#     z_1_equation = [round(round(equation[0]*10)/round(equation[2]*10)), round(round(equation[1]*10)/round(equation[2]*10)), 1, round(round(equation[3]*10)/round(equation[2]*10))]
# ZeroDivisionError: division by zero

# %%
main.stop()
# Out:
# sandbox.main_thread: INFO | Thread stopped.

# %% [markdown]
# # Test

# %%
main.stop()
main.run()
w.widgets_test()
# Out:
# sandbox.main_thread: INFO | Thread stopped.
# sandbox.main_thread: INFO | Thread started or resumed...
# C:\Users\6802923\AppData\Local\anaconda3\envs\sandbox-env\lib\threading.py:870: RuntimeWarning: coroutine 'MainThread.thread_loop' was never awaited
#   self._target(*self._args, **self._kwargs)
# Column
#     [0] Markdown(str)
#     [1] IntSlider(bar_color='#0000ff', end=400, name='x', start=1, value=100)
#     [2] IntSlider(bar_color='#0000ff', end=400, name='y', start=1, value=100)
# shape hex 149
# red [[50, 162]]
# blue [[48, 180]]
# green [[50, 144]]
# dark green [[49, 125]]
# shape hex 149
# red [[51, 162]]
# blue [[49, 180]]
# green [[50, 128], [50, 145]]
# dark green [[49, 125]]
# shape hex 149
# red [[50, 162]]
# blue [[48, 181]]
# green [[50, 144]]
# dark green [[49, 125]]
# shape hex 149
# red [[50, 162]]
# blue [[48, 181]]
# green [[50, 144]]
# dark green [[49, 125]]
