# %% [markdown]
# # Module vlakvergelijking

# %% [markdown]
# ## Initialize Sensor and Projector
# Do not change

# %%
#save the paths to the calibration files 
from sandbox import _calibration_dir
_calibprojector = _calibration_dir + "my_projector_calibration.json"
_calibsensor = _calibration_dir + "my_sensor_calibration.json"
_calibcolor = _calibration_dir + "my_color_calibration.json"

# %% [markdown]
# ## Choose the sensor
# for dummy sensor, use name="dummy"
# for kinectv2, use name="kinect_v2"

# %%
#Import Sensor
from sandbox.sensor import Sensor
sensor = Sensor(calibsensor=_calibsensor, calibcolor=_calibcolor, name="kinect_v2")
#sensor = Sensor(_calibsensor, name="dummy")
name="kinect_v2"

# Import projector
from sandbox.projector import Projector
projector = Projector(calibprojector=_calibprojector)
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='8c84ee8b-4508-4c3b-a0ef-153a6979ad5f'>
#   <div id="bb1a4696-6df4-46c5-b4d6-010e4edfd212" data-root-id="8c84ee8b-4508-4c3b-a0ef-153a6979ad5f" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"413e7596-9059-457d-9461-c81eb919c273":{"version":"3.1.1","title":"Bokeh Application","defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]}],"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"8c84ee8b-4508-4c3b-a0ef-153a6979ad5f"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"b97f5d27-45f0-46b3-8f45-28141471bf42","attributes":{"plot_id":"8c84ee8b-4508-4c3b-a0ef-153a6979ad5f","comm_id":"1126aa74e69448138381462cc45a2e1c","client_comm_id":"74c5f2ec29964136bfb332b6c1d2dfef"}}],"callbacks":{"type":"map"}}};
#   var render_items = [{"docid":"413e7596-9059-457d-9461-c81eb919c273","roots":{"8c84ee8b-4508-4c3b-a0ef-153a6979ad5f":"bb1a4696-6df4-46c5-b4d6-010e4edfd212"},"root_ids":["8c84ee8b-4508-4c3b-a0ef-153a6979ad5f"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   const is_dev = py_version.indexOf("+") !== -1 || py_version.indexOf("-") !== -1
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version && !is_dev) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# sandbox.sensor.sensor_api: INFO | JSON configuration loaded for sensor.
# sandbox.sensor.sensor_api: INFO | JSON configuration loaded for color sensor.
# sandbox.sensor.kinectV2: INFO | KinectV2 initialized.
# sandbox.projector.projector: INFO | JSON configuration loaded for projector
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# size 853 635
# Launching server at http://localhost:56056
# sandbox.projector.projector: INFO | Projector initialized and server started.
# Please position the browser window accordingly and enter fullscreen!

# %% [markdown]
# ## Load test data
# If we use the dummy sensor, we need to load test data.
# IF we use the kinect, we can run this code anyway.

# %%
import numpy as np
if name=="dummy":
    file = np.load("..\\06_LoadSaveTopoModule\saved_DEMs\DEM2.npz")
    frame = file['arr_0'] # + np.min(file['arr_0'])
    extent = np.asarray([0, frame.shape[1], 0, frame.shape[0], frame.min(), frame.max()])
    frame -= np.min(frame)

# %% [markdown]
# ## Initialize main thread for live update

# %%
from sandbox.main_thread import MainThread
main = MainThread(sensor=sensor, projector=projector, aruco=aruco if 'aruco' in globals() else None)
#main.load_frame(frame)
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='d58b148d-4e1f-4ca9-ab1c-8028fd92184b'>
#   <div id="f6675f72-2fe6-4ba5-8b14-660dc7955c64" data-root-id="d58b148d-4e1f-4ca9-ab1c-8028fd92184b" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"855eda03-a673-491d-acc9-dea692d5275d":{"version":"3.1.1","title":"Bokeh Application","defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]}],"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"d58b148d-4e1f-4ca9-ab1c-8028fd92184b"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"2b4cf02c-7586-462e-b7a8-9a3e4bb74c00","attributes":{"plot_id":"d58b148d-4e1f-4ca9-ab1c-8028fd92184b","comm_id":"a2830edb7e294eaf8226bf2940a6f520","client_comm_id":"d04e2d1234464d8b95de4bd1c44a2493"}}],"callbacks":{"type":"map"}}};
#   var render_items = [{"docid":"855eda03-a673-491d-acc9-dea692d5275d","roots":{"d58b148d-4e1f-4ca9-ab1c-8028fd92184b":"f6675f72-2fe6-4ba5-8b14-660dc7955c64"},"root_ids":["d58b148d-4e1f-4ca9-ab1c-8028fd92184b"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   const is_dev = py_version.indexOf("+") !== -1 || py_version.indexOf("-") !== -1
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version && !is_dev) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# sandbox.projector.contourlines: INFO | ContourLinesModule loaded successfully
# sandbox.projector.shading: INFO | LightSource set to address RWTH Aachen, Germany at datetime Tue Oct 22 10:48:40 2024
# sandbox.projector.cmap: INFO | CmapModule loaded successfully

# %% [markdown]
# ## import module and run the code

# %%
# Start the thread 
# Import the modules to use
from sandbox.modules import vlakvergelijking
Gradients = vlakvergelijking(extent=sensor.extent)
main.add_module(name='vlakvergelijking', module=Gradients)
main.run()
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='182dbc9b-c239-4346-b45e-a17fa2c29b96'>
#   <div id="ab0f5b8f-9da5-4be0-ad5f-3375f8c25e62" data-root-id="182dbc9b-c239-4346-b45e-a17fa2c29b96" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"275c9653-b016-404f-b319-26324ce3ef36":{"version":"3.1.1","title":"Bokeh Application","defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]}],"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"182dbc9b-c239-4346-b45e-a17fa2c29b96"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"752cb518-05a6-464c-a8ba-a44ad0451ffb","attributes":{"plot_id":"182dbc9b-c239-4346-b45e-a17fa2c29b96","comm_id":"f0eccd4b7fe9414c819de4c0e7045923","client_comm_id":"eeb55202661c4e12855474741b13c003"}}],"callbacks":{"type":"map"}}};
#   var render_items = [{"docid":"275c9653-b016-404f-b319-26324ce3ef36","roots":{"182dbc9b-c239-4346-b45e-a17fa2c29b96":"ab0f5b8f-9da5-4be0-ad5f-3375f8c25e62"},"root_ids":["182dbc9b-c239-4346-b45e-a17fa2c29b96"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   const is_dev = py_version.indexOf("+") !== -1 || py_version.indexOf("-") !== -1
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version && !is_dev) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# sandbox.modules.vlakvergelijking: INFO | VlakModules loaded successfully
# sandbox.main_thread: INFO | module vlakvergelijking added to modules
# sandbox.main_thread: INFO | Thread started or resumed...
# C:\Users\6802923\AppData\Local\anaconda3\envs\sandbox-env\lib\threading.py:870: RuntimeWarning: coroutine 'MainThread.thread_loop' was never awaited
#   self._target(*self._args, **self._kwargs)
# the color [147.  67.  44.]
# the color [153.  66.  44.]
# the color [141.  69.  45.]
# the color [169.  62.  40.]
# the color [166.  53.  32.]
# the color [160.  47.  26.]
# the color [172.  51.  24.]
# the color [171.  49.  18.]
# the color [174.  55.  28.]
# the color [160.  60.  35.]
# the color [145.  61.  37.]
# the color [174.  56.  31.]
# the color [179.  56.  28.]
# the color [175.  51.  18.]
# the color [176.  53.  25.]
# the color [174.  55.  30.]
# the color [160.  64.  39.]
# the color [175.  59.  35.]
# the color [180.  57.  30.]
# the color [183.  54.  26.]
# the color [175.  49.  16.]
# the color [187.  55.  25.]
# the color [185.  53.  26.]
# the color [184.  56.  30.]
# the color [162.  69.  47.]
# the color [177.  53.  29.]
# the color [181.  53.  27.]
# the color [181.  52.  22.]
# the color [178.  47.  15.]
# the color [180.  48.  18.]
# the color [179.  47.  20.]
# the color [186.  56.  30.]
# the color [178.  58.  37.]
# the color [140.  53.  31.]
# the color [129.  47.  24.]
# the color [174.  50.  26.]
# the color [179.  49.  23.]
# the color [175.  48.  20.]
# the color [174.  43.  13.]
# the color [179.  47.  17.]
# the color [179.  48.  18.]
# the color [188.  56.  24.]
# the color [187.  60.  30.]
# the color [184.  61.  34.]
# the color [173.  59.  35.]
# the color [171.  77.  55.]
# the color [199.  83.  58.]
# the color [179.  54.  27.]
# the color [175.  50.  22.]
# the color [174.  43.  13.]
# the color [181.  47.  17.]
# the color [183.  49.  17.]
# the color [182.  50.  18.]
# the color [178.  56.  23.]
# the color [173.  55.  26.]
# the color [170.  58.  33.]
# the color [181.  87.  64.]
# the color [186.  56.  70.]
# the color [184.  55.  64.]
# the color [184.  52.  62.]
# the color [184.  54.  66.]
# the color [185.  52.  68.]
# the color [183.  56.  78.]
# the color [175.  57.  84.]
# the color [183.  59.  78.]
# the color [185.  57.  75.]
# the color [181.  54.  68.]
# the color [183.  53.  65.]
# the color [186.  56.  68.]
# the color [181.  53.  67.]
# the color [182.  51.  69.]
# the color [174.  49.  74.]
# the color [176.  58.  83.]
# the color [177.  55.  76.]
# the color [182.  54.  73.]
# the color [186.  55.  71.]
# the color [180.  51.  67.]
# the color [182.  51.  69.]
# the color [184.  55.  71.]
# the color [174.  58.  85.]
# the color [180.  55.  78.]
# the color [186.  58.  76.]
# the color [183.  54.  72.]
# the color [184.  55.  73.]
# the color [186.  57.  79.]
# the color [178.  60.  87.]
# the color [182.  59.  82.]
# the color [182.  54.  72.]
# the color [186.  57.  79.]
# the color [168.  52.  80.]
# the color [176.  53.  78.]
# the color [175.  47.  73.]
# [[67, 296]]
# number of distinct red points 1
# [[67, 296]]
# border x, y 412 245
# 63.517321980445786
# p [-3 -2  1]
# not enough points found, try again
# the color [158.  63.  78.]
# the color [181.  74.  90.]
# the color [183.  74.  88.]
# the color [185.  72.  85.]
# the color [184.  69.  82.]
# the color [184.  70.  80.]
# the color [187.  73.  83.]
# the color [183.  70.  84.]
# the color [188.  77.  90.]
# the color [185.  73.  83.]
# the color [184.  70.  78.]
# the color [183.  71.  79.]
# the color [186.  72.  82.]
# the color [180.  67.  80.]
# the color [182.  71.  87.]
# the color [187.  72.  85.]
# the color [186.  72.  82.]
# the color [187.  71.  82.]
# the color [186.  71.  79.]
# the color [183.  69.  79.]
# the color [186.  77.  91.]
# the color [178.  69.  85.]
# the color [182.  65.  80.]
# the color [184.  64.  77.]
# the color [185.  65.  76.]
# the color [183.  67.  80.]
# the color [183.  70.  84.]
# the color [184.  73.  89.]
# the color [182.  66.  79.]
# the color [188.  70.  83.]
# the color [184.  68.  81.]
# the color [177.  70.  84.]
# the color [185.  72.  86.]
# the color [181.  70.  86.]
# the color [179.  72.  88.]
# the color [171.  63.  81.]
# [[121, 273]]
# number of distinct red points 1
# [[121, 273]]
# border x, y 412 245
# 56.53640334111401
# p [-2  0  1]
# not enough points found, try again

# %% [markdown]
# ## Add widgets

# %%
Gradients.show_widgets()
# Out:
# Column
#     [0] Markdown(str)
#     [1] Checkbox(name='Show colors', value=True)
#     [2] Checkbox(name='Show contours')
#     [3] Checkbox(name='Show axes')
#     [4] Button(button_type='primary', name='Find plane equation')
#     [5] Button(button_type='primary', name='Find vector equation')
#     [6] Button(button_type='primary', name='get random equation')
#     [7] IntSlider(bar_color='#0000ff', end=400, name='y', start=1, value=100)
#     [8] IntSlider(bar_color='#0000ff', end=400, name='x', start=1, value=100)
#     [9] Checkbox(name='draw point')
#     [10] Button(button_type='primary', name='Show red points')

# %%
main.widget_plot_module()
# Out:
# Tabs
#     [0] Column
#         [0] Markdown(str)
#         [1] Row
#             [0] Column
#                 [0] Column
#                     [0] Markdown(str)
#                     [1] Checkbox(name='Show colormap', value=True)
#                     [2] Select(name='Choose a colormap', options=['gist_earth', ...], value='gist_earth')
#                     [3] Column
#                         [0] Markdown(str)
#                         [1] Checkbox(name='Show relief shading', value=True)
#                         [2] Tabs
#                             [0] WidgetBox
#                                 [0] Checkbox(name='Manual configuration')
#                                 [1] FloatSlider(end=360.0, name='Azimuth', value=162.70545893091924)
#                                 [2] FloatSlider(end=90.0, name='Altitude', value=28.274847230609012)
#                                 [3] FloatInput(name='Vertical Exageration', step=0.01, value=0.25)
#                             [1] WidgetBox
#                                 [0] TextInput(name='Enter address (e.g. City,..., value='RWTH Aachen, Germany')
#                                 [1] DatePicker(name='Select date (UTC +0)', value=datetime.date(2024, ...)
#                                 [2] Row(width_policy='min')
#                                     [0] IntSlider(end=23, name='Hour', value=10, width_policy='min')
#                                     [1] IntSlider(end=59, name='Minute', value=19, width_policy='min')
#                                     [2] IntSlider(end=59, name='Second', value=20, width_policy='min')
#                                 [3] Markdown(str, sizing_mode='scale_width')
#                                 [4] Markdown(str, sizing_mode='scale_width')
#                                 [5] Markdown(str, sizing_mode='scale_width')
#                                 [6] Markdown(str, sizing_mode='scale_width')
#                             [2] WidgetBox
#                                 [0] Checkbox(name='Start day simulation i...)
#                 [1] Column
#                     [0] Markdown(str)
#                     [1] Checkbox(name='Active contours', value=True)
#                     [2] Checkbox(name='Automatic levels f...)
#                     [3] Markdown(str)
#                     [4] WidgetBox
#                         [0] Checkbox(name='Show major contours', value=True)
#                         [1] IntInput(name='Choose a contour step', value=100)
#                         [2] Checkbox(name='Show minor contours', value=True)
#                         [3] IntInput(name='Choose a minor c..., value=10)
#                         [4] Checkbox(name='Show contours label')
#                         [5] IntInput(name='set a contour l..., value=15)
#             [1] Column
#                 [0] Markdown(str)
#                 [1] RadioButtonGroup(button_type='success', name='Thread controller', options=['Start', 'Stop'], value='Start')
#                 [2] Checkbox(name='Check changes in fame')
#                 [3] CrossSelector(definition_order=False, name='Module manager', options=['CmapModule', ...], value=['CmapModule', ...])
#                 [4] Button(button_type='warning', name='Clear axes from p...)
#                 [5] Markdown(str)
#     [1] Tabs
#         [0] Row
#             [0] Column
#                 [0] Markdown(str)
#                 [1] Checkbox(name='Show colorbar')
#                 [2] TextInput(name='Label of colorbar')
#                 [3] Button(button_type='success', name='Refresh label')
#             [1] Column
#                 [0] Select(name='Orientation Colorbar', options=['vertical', '...], value='vertical')
#                 [1] IntSlider(end=748, name='Top space')
#                 [2] IntSlider(end=1004, name='Left space')
#                 [3] IntSlider(end=1024, name='Width Colorbar', start=1, value=70)
#                 [4] IntSlider(end=768, name='Height colorbar', start=1, value=500)
#                 [5] ColorPicker(name='Color background c..., value='#2896A5')
#         [1] Row
#             [0] Column
#                 [0] Markdown(str)
#                 [1] Checkbox(name='Show legend')
#                 [2] Button(button_type='success', name='Refresh legend')
#             [1] Column
#                 [0] IntSlider(end=748, name='Top space')
#                 [1] IntSlider(end=1004, name='Left space')
#                 [2] IntSlider(end=1024, name='Width Legend', start=1, value=175)
#                 [3] IntSlider(end=768, name='Height Legend', start=1, value=233)
#                 [4] ColorPicker(name='Color background c..., value='#16425B')

# %%
main.stop()
# Out:
# sandbox.main_thread: INFO | Thread stopped.
