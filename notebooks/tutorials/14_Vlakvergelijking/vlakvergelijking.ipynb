# %% [markdown]
# # Module vlakvergelijking

# %% [markdown]
# ## Initialize Sensor and Projector
# Do not change

# %%
#save the paths to the calibration files 
from sandbox import _calibration_dir
_calibprojector = _calibration_dir + "my_projector_calibration.json"
_calibsensor = _calibration_dir + "my_sensor_calibration.json"
_calibcolor = _calibration_dir + "my_color_calibration.json"

# %% [markdown]
# ## Choose the sensor
# for dummy sensor, use name="dummy"
# for kinectv2, use name="kinect_v2"

# %%
#Import Sensor
from sandbox.sensor import Sensor
sensor = Sensor(calibsensor=_calibsensor, calibcolor=_calibcolor, name="kinect_v2")
#sensor = Sensor(_calibsensor, name="dummy")
name="kinect_v2"

# Import projector
from sandbox.projector import Projector
projector = Projector(calibprojector=_calibprojector)
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='7cc2a809-8ce4-4a43-b3f5-99f2a795cd15'>
#   <div id="d7ccf5d3-b700-41a8-b0ae-871e64b5a8c3" data-root-id="7cc2a809-8ce4-4a43-b3f5-99f2a795cd15" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"4c3d1eb2-6d75-4a33-8c1a-7e8a02055651":{"version":"3.1.1","title":"Bokeh Application","defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]}],"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"7cc2a809-8ce4-4a43-b3f5-99f2a795cd15"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"cadf5166-130c-4d52-983e-cdd4e6f8221f","attributes":{"plot_id":"7cc2a809-8ce4-4a43-b3f5-99f2a795cd15","comm_id":"196fc3e6e8b943469df8df42f0c586e4","client_comm_id":"61a734f8e55f4543a12a21800423fee3"}}],"callbacks":{"type":"map"}}};
#   var render_items = [{"docid":"4c3d1eb2-6d75-4a33-8c1a-7e8a02055651","roots":{"7cc2a809-8ce4-4a43-b3f5-99f2a795cd15":"d7ccf5d3-b700-41a8-b0ae-871e64b5a8c3"},"root_ids":["7cc2a809-8ce4-4a43-b3f5-99f2a795cd15"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   const is_dev = py_version.indexOf("+") !== -1 || py_version.indexOf("-") !== -1
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version && !is_dev) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# sandbox.sensor.sensor_api: INFO | JSON configuration loaded for sensor.
# sandbox.sensor.sensor_api: INFO | JSON configuration loaded for color sensor.
# sandbox.sensor.kinectV2: INFO | KinectV2 initialized.
# sandbox.projector.projector: INFO | JSON configuration loaded for projector
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# size 830 540
# Launching server at http://localhost:53700
# sandbox.projector.projector: INFO | Projector initialized and server started.
# Please position the browser window accordingly and enter fullscreen!

# %% [markdown]
# ## Load test data
# If we use the dummy sensor, we need to load test data.
# IF we use the kinect, we can run this code anyway.

# %%
import numpy as np
if name=="dummy":
    file = np.load("..\\06_LoadSaveTopoModule\saved_DEMs\DEM2.npz")
    frame = file['arr_0'] # + np.min(file['arr_0'])
    extent = np.asarray([0, frame.shape[1], 0, frame.shape[0], frame.min(), frame.max()])
    frame -= np.min(frame)

# %% [markdown]
# ## Initialize main thread for live update

# %%
from sandbox.main_thread import MainThread
main = MainThread(sensor=sensor, projector=projector, aruco=aruco if 'aruco' in globals() else None)
#main.load_frame(frame)
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='06261492-2db1-476b-a904-c089c7a8324d'>
#   <div id="ed985959-8e8f-4cd3-837e-a15778d2bd0d" data-root-id="06261492-2db1-476b-a904-c089c7a8324d" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"3059ecbb-955b-425e-abcd-df4b1b877c1c":{"version":"3.1.1","title":"Bokeh Application","defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]}],"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"06261492-2db1-476b-a904-c089c7a8324d"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"943397c3-392a-4fdf-aa3a-90ff0d82ecbf","attributes":{"plot_id":"06261492-2db1-476b-a904-c089c7a8324d","comm_id":"1c75721bb8434767a719899986285360","client_comm_id":"03683783d67f49f18dc0b18c68562aa2"}}],"callbacks":{"type":"map"}}};
#   var render_items = [{"docid":"3059ecbb-955b-425e-abcd-df4b1b877c1c","roots":{"06261492-2db1-476b-a904-c089c7a8324d":"ed985959-8e8f-4cd3-837e-a15778d2bd0d"},"root_ids":["06261492-2db1-476b-a904-c089c7a8324d"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   const is_dev = py_version.indexOf("+") !== -1 || py_version.indexOf("-") !== -1
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version && !is_dev) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# sandbox.projector.contourlines: INFO | ContourLinesModule loaded successfully
# sandbox.projector.shading: INFO | LightSource set to address RWTH Aachen, Germany at datetime Tue Nov 19 12:40:10 2024
# sandbox.projector.cmap: INFO | CmapModule loaded successfully
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# sandbox.modules.widgets: INFO | widgets created

# %% [markdown]
# ## import modules and run the code
# Make sure the surface is flat before running this code

# %%
# Start the thread 
# Import the modules to use
from sandbox.modules import vlakvergelijking
from sandbox.modules import widgets
w = widgets()
Gradients = vlakvergelijking(extent=sensor.extent)
main.add_module(name='widgets', module=w)
main.add_module(name='vlakvergelijking', module=Gradients)
main.run()
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='7968e1e5-d71f-4cf3-a269-2242eb399955'>
#   <div id="d2e80a57-8130-470c-b4d9-2460e4b5a4df" data-root-id="7968e1e5-d71f-4cf3-a269-2242eb399955" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"86d561d6-63ca-4732-8f23-9853195ca416":{"version":"3.1.1","title":"Bokeh Application","defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]}],"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"7968e1e5-d71f-4cf3-a269-2242eb399955"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"e3fffc1c-73e1-4d9b-87ef-249821210476","attributes":{"plot_id":"7968e1e5-d71f-4cf3-a269-2242eb399955","comm_id":"86b1545451074b47a5e8f44753237aba","client_comm_id":"f6410e8c30c5486990b1c128eb7e1fd9"}}],"callbacks":{"type":"map"}}};
#   var render_items = [{"docid":"86d561d6-63ca-4732-8f23-9853195ca416","roots":{"7968e1e5-d71f-4cf3-a269-2242eb399955":"d2e80a57-8130-470c-b4d9-2460e4b5a4df"},"root_ids":["7968e1e5-d71f-4cf3-a269-2242eb399955"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   const is_dev = py_version.indexOf("+") !== -1 || py_version.indexOf("-") !== -1
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version && !is_dev) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# sandbox.modules.widgets: INFO | widgets created
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# sandbox.modules.vlakvergelijking: INFO | VlakModules loaded successfully
# sandbox.main_thread: INFO | module widgets added to modules
# sandbox.main_thread: INFO | module vlakvergelijking added to modules
# sandbox.main_thread: INFO | Thread started or resumed...
# C:\Users\6802923\AppData\Local\anaconda3\envs\sandbox-env\lib\threading.py:870: RuntimeWarning: coroutine 'MainThread.thread_loop' was never awaited
#   self._target(*self._args, **self._kwargs)

# %% [markdown]
# # Tutorial
# Run the code below to do the tutorial.

# %%
main.stop()
main.run()
w.widgets_tutorial()
# Out:
# sandbox.main_thread: INFO | Thread stopped.
# sandbox.main_thread: INFO | Thread started or resumed...
# C:\Users\6802923\AppData\Local\anaconda3\envs\sandbox-env\lib\threading.py:870: RuntimeWarning: coroutine 'MainThread.thread_loop' was never awaited
#   self._target(*self._args, **self._kwargs)
# Column
#     [0] Markdown(str)
#     [1] Checkbox(name='Show exercise d..., value=True)

# %% [markdown]
# # Exercise 1

# %%
main.stop()
main.run()
w.widgets_exercise1()
# Out:
# sandbox.main_thread: INFO | Thread stopped.
# sandbox.main_thread: INFO | Thread started or resumed...
# C:\Users\6802923\AppData\Local\anaconda3\envs\sandbox-env\lib\threading.py:870: RuntimeWarning: coroutine 'MainThread.thread_loop' was never awaited
#   self._target(*self._args, **self._kwargs)
# Column
#     [0] Markdown(str)
#     [1] Checkbox(name='Show exercise d..., value=True)

# %% [markdown]
# # Exercise 2

# %%
main.stop()
main.run()
w.widgets_exercise2()
# Out:
# sandbox.main_thread: INFO | Thread stopped.
# sandbox.main_thread: INFO | Thread started or resumed...
# C:\Users\6802923\AppData\Local\anaconda3\envs\sandbox-env\lib\threading.py:870: RuntimeWarning: coroutine 'MainThread.thread_loop' was never awaited
#   self._target(*self._args, **self._kwargs)
# Column
#     [0] Markdown(str)
#     [1] Checkbox(name='Show exercise d..., value=True)

# %% [markdown]
# # Exercise 3

# %%
main.stop()
main.run()
w.widgets_exercise3()
# Out:
# sandbox.main_thread: INFO | Thread stopped.
# sandbox.main_thread: INFO | Thread started or resumed...
# C:\Users\6802923\AppData\Local\anaconda3\envs\sandbox-env\lib\threading.py:870: RuntimeWarning: coroutine 'MainThread.thread_loop' was never awaited
#   self._target(*self._args, **self._kwargs)
# Column
#     [0] Markdown(str)
#     [1] Checkbox(name='Show exercise d..., value=True)

# %% [markdown]
# # Exercise 4

# %%
main.stop()
main.run()
w.widgets_exercise4()
# Out:
# sandbox.main_thread: INFO | Thread stopped.
# sandbox.main_thread: INFO | Thread started or resumed...
# C:\Users\6802923\AppData\Local\anaconda3\envs\sandbox-env\lib\threading.py:870: RuntimeWarning: coroutine 'MainThread.thread_loop' was never awaited
#   self._target(*self._args, **self._kwargs)
# Column
#     [0] Markdown(str)
#     [1] Checkbox(name='Show exercise d..., value=True)
#     [2] Button(button_type='primary', name='Show a vector')
#     [3] Checkbox(name='Find vector equation')

# %% [markdown]
# # Exercise 5

# %%
main.stop()
main.run()
w.widgets_exercise5()
# Out:
# sandbox.main_thread: INFO | Thread stopped.
# sandbox.main_thread: INFO | Thread started or resumed...
# C:\Users\6802923\AppData\Local\anaconda3\envs\sandbox-env\lib\threading.py:870: RuntimeWarning: coroutine 'MainThread.thread_loop' was never awaited
#   self._target(*self._args, **self._kwargs)
# Column
#     [0] Markdown(str)
#     [1] Checkbox(name='Show exercise d..., value=True)

# %% [markdown]
# # Exercise 6

# %%
main.stop()
main.run()
w.widgets_exercise6()
# Out:
# sandbox.main_thread: INFO | Thread stopped.
# sandbox.main_thread: INFO | Thread started or resumed...
# C:\Users\6802923\AppData\Local\anaconda3\envs\sandbox-env\lib\threading.py:870: RuntimeWarning: coroutine 'MainThread.thread_loop' was never awaited
#   self._target(*self._args, **self._kwargs)
# Column
#     [0] Markdown(str)
#     [1] Checkbox(name='Show exercise d..., value=True)

# %% [markdown]
# # Exercise 7

# %%
main.stop()
main.run()
w.widgets_exercise7()

# %% [markdown]
# # Exercise 8

# %%
main.stop()
main.run()
w.widgets_exercise8()

# %% [markdown]
# # Exercise 9

# %%
main.stop()
main.run()
w.widgets_exercise9()

# %%
main.stop()
# Out:
# sandbox.main_thread: INFO | Thread stopped.

# %% [markdown]
# # Test

# %%
main.stop()
main.run()
w.widgets_test()
# Out:
# sandbox.main_thread: INFO | Thread stopped.
# sandbox.main_thread: INFO | Thread started or resumed...
# C:\Users\6802923\AppData\Local\anaconda3\envs\sandbox-env\lib\threading.py:870: RuntimeWarning: coroutine 'MainThread.thread_loop' was never awaited
#   self._target(*self._args, **self._kwargs)
# Column
#     [0] Markdown(str)
#     [1] IntSlider(bar_color='#0000ff', end=400, name='x', start=1, value=100)
#     [2] IntSlider(bar_color='#0000ff', end=400, name='y', start=1, value=100)
# (197, 312, 3)
# red points []
# not enough red points
# (197, 312, 3)
# red points []
# not enough red points
# (197, 312, 3)
# red points []
# not enough red points
# (197, 312, 3)
# red points []
# not enough red points
# (197, 312, 3)
# red points []
# not enough red points
# (197, 312, 3)
# red points []
# not enough red points
# (197, 312, 3)
# red points []
# not enough red points
# (197, 312, 3)
# red points []
# not enough red points
# (197, 312, 3)
# red points []
# not enough red points
# (197, 312, 3)
# red points []
# not enough red points
# (197, 312, 3)
# red points []
# not enough red points

# %%
main.stop()
# Out:
# sandbox.main_thread: INFO | Thread stopped.
